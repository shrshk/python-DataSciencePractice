# %%
import pandas as pd

# %%
xlsFile = pd.ExcelFile('capbudg.xls')

# %%
dframe = xlsFile.parse()

# %%
dframe
# Out:
#                          Equity Analysis of a Project           Unnamed: 1  \
# 0                                                 NaN                  NaN
# 1                                  INITIAL INVESTMENT                  NaN
# 2                                 Initial Investment=                  NaN
# 3                          Opportunity cost (if any)=                  NaN
# 4                          Lifetime of the investment                  NaN
# 5                    Salvage Value at end of project=                  NaN
# 6                    Deprec. method(1:St.line;2:DDB)=                  NaN
# 7                               Tax Credit (if any )=                  NaN
# 8                     Other invest.(non-depreciable)=                  NaN
# 9                                                 NaN                  NaN
# 10                                    WORKING CAPITAL                  NaN
# ...
